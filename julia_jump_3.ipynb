# %% [markdown]
# Import necessary pakages

# %%
using JuMP
using HiGHS

# %%
X_coor = [55 58 60 64 70 66 71 72 73 76 68 68 75 70]
Y_coor = [60 55 54 56 65 63 60 50 66 44 43 67 47 42]
n = length(X_coor) # number of points
k = 3 # number of clusters
# Out:
# 3

# %%
d = Array{Float64}(undef, n, n)
for i=1:n
    for j=1:n
        d[i, j] = sqrt((X_coor[i] - X_coor[j])^2 + (Y_coor[i] - Y_coor[j])^2)
    end
end

# %%
model = Model(HiGHS.Optimizer)
@variable(model, x[i=1:n], Bin) # x is indicator variable states weather or not point i is selected as a medoid
@variable(model, y[i=1:n, j=1:n], Bin) # y is an indicator variable states weather point j is assigned to cluster of meodoid-i
@objective(model, Min, sum(d[i,j] * y[i,j] for i=1:k for j=1:n))
# There can be only 3 clusters
@constraint(model, sum(x[i] for i=1:n) == 3)
# Each point should be assigned to only one cluster
@constraint(model, [j=1:n], sum(y[i,j] for i=1:n) == 1)
# Each cluster should have one medoid point
@constraint(model, [i=1:n, j=1:n], y[i,j] <= x[i])
# If a point is assigned as a medoid of a cluster, then this point should within that cluster.
@constraint(model, [i=1:n], x[i] <= y[i,i])

print(model)
optimize!(model)

println("Termination status: $(termination_status(model))")
if termination_status(model) == MOI.OPTIMAL
    println("Optimal objective value: $(objective_value(model))")
    println("Selected medoid points:")
    for i=1:n
        if value(x[i])>0
            println("======================")
            println("New Cluster")
            println("======================")
            println("Medoid Point: $(i)")
            println("Assigned points")
            for j=1:n
                if value(y[i,j])>0
                    println("Point: $(j)")
                end
            end
        end
    end
else
    println("No optimal solution available")
end
# Out:
# $$ \begin{aligned}
# \min\quad & 5.830951894845301 y_{1,2} + 7.810249675906654 y_{1,3} + 9.848857801796104 y_{1,4} + 15.811388300841896 y_{1,5} + 11.40175425099138 y_{1,6} + 16 y_{1,7} + 19.72308292331602 y_{1,8} + 18.973665961010276 y_{1,9} + 26.40075756488817 y_{1,10} + 21.400934559032695 y_{1,11} + 14.7648230602334 y_{1,12} + 23.853720883753127 y_{1,13} + 23.430749027719962 y_{1,14} + 5.830951894845301 y_{2,1} + 2.23606797749979 y_{2,3} + 6.082762530298219 y_{2,4} + 15.620499351813308 y_{2,5} + 11.313708498984761 y_{2,6} + 13.92838827718412 y_{2,7} + 14.866068747318506 y_{2,8} + 18.601075237738275 y_{2,9} + 21.095023109728988 y_{2,10} + 15.620499351813308 y_{2,11} + 15.620499351813308 y_{2,12} + 18.788294228055936 y_{2,13} + 17.69180601295413 y_{2,14} + 7.810249675906654 y_{3,1} + 2.23606797749979 y_{3,2} + 4.47213595499958 y_{3,4} + 14.866068747318506 y_{3,5} + 10.816653826391969 y_{3,6} + 12.529964086141668 y_{3,7} + 12.649110640673518 y_{3,8} + 17.69180601295413 y_{3,9} + 18.867962264113206 y_{3,10} + 13.601470508735444 y_{3,11} + 15.264337522473747 y_{3,12} + 16.55294535724685 y_{3,13} + 15.620499351813308 y_{3,14}\\
# \text{Subject to} \quad & x_{1} + x_{2} + x_{3} + x_{4} + x_{5} + x_{6} + x_{7} + x_{8} + x_{9} + x_{10} + x_{11} + x_{12} + x_{13} + x_{14} = 3\\
#  & y_{1,1} + y_{2,1} + y_{3,1} + y_{4,1} + y_{5,1} + y_{6,1} + y_{7,1} + y_{8,1} + y_{9,1} + y_{10,1} + y_{11,1} + y_{12,1} + y_{13,1} + y_{14,1} = 1\\
#  & y_{1,2} + y_{2,2} + y_{3,2} + y_{4,2} + y_{5,2} + y_{6,2} + y_{7,2} + y_{8,2} + y_{9,2} + y_{10,2} + y_{11,2} + y_{12,2} + y_{13,2} + y_{14,2} = 1\\
#  & y_{1,3} + y_{2,3} + y_{3,3} + y_{4,3} + y_{5,3} + y_{6,3} + y_{7,3} + y_{8,3} + y_{9,3} + y_{10,3} + y_{11,3} + y_{12,3} + y_{13,3} + y_{14,3} = 1\\
#  & y_{1,4} + y_{2,4} + y_{3,4} + y_{4,4} + y_{5,4} + y_{6,4} + y_{7,4} + y_{8,4} + y_{9,4} + y_{10,4} + y_{11,4} + y_{12,4} + y_{13,4} + y_{14,4} = 1\\
#  & y_{1,5} + y_{2,5} + y_{3,5} + y_{4,5} + y_{5,5} + y_{6,5} + y_{7,5} + y_{8,5} + y_{9,5} + y_{10,5} + y_{11,5} + y_{12,5} + y_{13,5} + y_{14,5} = 1\\
#  & y_{1,6} + y_{2,6} + y_{3,6} + y_{4,6} + y_{5,6} + y_{6,6} + y_{7,6} + y_{8,6} + y_{9,6} + y_{10,6} + y_{11,6} + y_{12,6} + y_{13,6} + y_{14,6} = 1\\
#  & y_{1,7} + y_{2,7} + y_{3,7} + y_{4,7} + y_{5,7} + y_{6,7} + y_{7,7} + y_{8,7} + y_{9,7} + y_{10,7} + y_{11,7} + y_{12,7} + y_{13,7} + y_{14,7} = 1\\
#  & y_{1,8} + y_{2,8} + y_{3,8} + y_{4,8} + y_{5,8} + y_{6,8} + y_{7,8} + y_{8,8} + y_{9,8} + y_{10,8} + y_{11,8} + y_{12,8} + y_{13,8} + y_{14,8} = 1\\
#  & y_{1,9} + y_{2,9} + y_{3,9} + y_{4,9} + y_{5,9} + y_{6,9} + y_{7,9} + y_{8,9} + y_{9,9} + y_{10,9} + y_{11,9} + y_{12,9} + y_{13,9} + y_{14,9} = 1\\
#  & y_{1,10} + y_{2,10} + y_{3,10} + y_{4,10} + y_{5,10} + y_{6,10} + y_{7,10} + y_{8,10} + y_{9,10} + y_{10,10} + y_{11,10} + y_{12,10} + y_{13,10} + y_{14,10} = 1\\
#  & y_{1,11} + y_{2,11} + y_{3,11} + y_{4,11} + y_{5,11} + y_{6,11} + y_{7,11} + y_{8,11} + y_{9,11} + y_{10,11} + y_{11,11} + y_{12,11} + y_{13,11} + y_{14,11} = 1\\
#  & y_{1,12} + y_{2,12} + y_{3,12} + y_{4,12} + y_{5,12} + y_{6,12} + y_{7,12} + y_{8,12} + y_{9,12} + y_{10,12} + y_{11,12} + y_{12,12} + y_{13,12} + y_{14,12} = 1\\
#  & y_{1,13} + y_{2,13} + y_{3,13} + y_{4,13} + y_{5,13} + y_{6,13} + y_{7,13} + y_{8,13} + y_{9,13} + y_{10,13} + y_{11,13} + y_{12,13} + y_{13,13} + y_{14,13} = 1\\
#  & y_{1,14} + y_{2,14} + y_{3,14} + y_{4,14} + y_{5,14} + y_{6,14} + y_{7,14} + y_{8,14} + y_{9,14} + y_{10,14} + y_{11,14} + y_{12,14} + y_{13,14} + y_{14,14} = 1\\
#  & -x_{1} + y_{1,1} \leq 0\\
#  & -x_{2} + y_{2,1} \leq 0\\
#  & -x_{3} + y_{3,1} \leq 0\\
#  & -x_{4} + y_{4,1} \leq 0\\
#  & -x_{5} + y_{5,1} \leq 0\\
#  & -x_{6} + y_{6,1} \leq 0\\
#  & -x_{7} + y_{7,1} \leq 0\\
#  & -x_{8} + y_{8,1} \leq 0\\
#  & -x_{9} + y_{9,1} \leq 0\\
#  & -x_{10} + y_{10,1} \leq 0\\
#  & -x_{11} + y_{11,1} \leq 0\\
#  & -x_{12} + y_{12,1} \leq 0\\
#  & -x_{13} + y_{13,1} \leq 0\\
#  & -x_{14} + y_{14,1} \leq 0\\
#  & -x_{1} + y_{1,2} \leq 0\\
#  & -x_{2} + y_{2,2} \leq 0\\
#  & -x_{3} + y_{3,2} \leq 0\\
#  & -x_{4} + y_{4,2} \leq 0\\
#  & -x_{5} + y_{5,2} \leq 0\\
#  & -x_{6} + y_{6,2} \leq 0\\
#  & -x_{7} + y_{7,2} \leq 0\\
#  & -x_{8} + y_{8,2} \leq 0\\
#  & -x_{9} + y_{9,2} \leq 0\\
#  & -x_{10} + y_{10,2} \leq 0\\
#  & -x_{11} + y_{11,2} \leq 0\\
#  & -x_{12} + y_{12,2} \leq 0\\
#  & -x_{13} + y_{13,2} \leq 0\\
#  & -x_{14} + y_{14,2} \leq 0\\
#  & -x_{1} + y_{1,3} \leq 0\\
#  & -x_{2} + y_{2,3} \leq 0\\
#  & -x_{3} + y_{3,3} \leq 0\\
#  & -x_{4} + y_{4,3} \leq 0\\
#  & -x_{5} + y_{5,3} \leq 0\\
#  & -x_{6} + y_{6,3} \leq 0\\
#  & -x_{7} + y_{7,3} \leq 0\\
#  & [[\ldots\text{335 constraints skipped}\ldots]] \\
#  & y_{7,11} \in \{0, 1\}\\
#  & y_{8,11} \in \{0, 1\}\\
#  & y_{9,11} \in \{0, 1\}\\
#  & y_{10,11} \in \{0, 1\}\\
#  & y_{11,11} \in \{0, 1\}\\
#  & y_{12,11} \in \{0, 1\}\\
#  & y_{13,11} \in \{0, 1\}\\
#  & y_{14,11} \in \{0, 1\}\\
#  & y_{1,12} \in \{0, 1\}\\
#  & y_{2,12} \in \{0, 1\}\\
#  & y_{3,12} \in \{0, 1\}\\
#  & y_{4,12} \in \{0, 1\}\\
#  & y_{5,12} \in \{0, 1\}\\
#  & y_{6,12} \in \{0, 1\}\\
#  & y_{7,12} \in \{0, 1\}\\
#  & y_{8,12} \in \{0, 1\}\\
#  & y_{9,12} \in \{0, 1\}\\
#  & y_{10,12} \in \{0, 1\}\\
#  & y_{11,12} \in \{0, 1\}\\
#  & y_{12,12} \in \{0, 1\}\\
#  & y_{13,12} \in \{0, 1\}\\
#  & y_{14,12} \in \{0, 1\}\\
#  & y_{1,13} \in \{0, 1\}\\
#  & y_{2,13} \in \{0, 1\}\\
#  & y_{3,13} \in \{0, 1\}\\
#  & y_{4,13} \in \{0, 1\}\\
#  & y_{5,13} \in \{0, 1\}\\
#  & y_{6,13} \in \{0, 1\}\\
#  & y_{7,13} \in \{0, 1\}\\
#  & y_{8,13} \in \{0, 1\}\\
#  & y_{9,13} \in \{0, 1\}\\
#  & y_{10,13} \in \{0, 1\}\\
#  & y_{11,13} \in \{0, 1\}\\
#  & y_{12,13} \in \{0, 1\}\\
#  & y_{13,13} \in \{0, 1\}\\
#  & y_{14,13} \in \{0, 1\}\\
#  & y_{1,14} \in \{0, 1\}\\
#  & y_{2,14} \in \{0, 1\}\\
#  & y_{3,14} \in \{0, 1\}\\
#  & y_{4,14} \in \{0, 1\}\\
#  & y_{5,14} \in \{0, 1\}\\
#  & y_{6,14} \in \{0, 1\}\\
#  & y_{7,14} \in \{0, 1\}\\
#  & y_{8,14} \in \{0, 1\}\\
#  & y_{9,14} \in \{0, 1\}\\
#  & y_{10,14} \in \{0, 1\}\\
#  & y_{11,14} \in \{0, 1\}\\
#  & y_{12,14} \in \{0, 1\}\\
#  & y_{13,14} \in \{0, 1\}\\
#  & y_{14,14} \in \{0, 1\}\\
# \end{aligned} $$
# Running HiGHS 1.9.0 (git hash: 66f735e60): Copyright (c) 2024 HiGHS under MIT licence terms
# Coefficient ranges:
#   Matrix [1e+00, 1e+00]
#   Cost   [2e+00, 3e+01]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e+00, 3e+00]
# Presolving model
# 225 rows, 210 cols, 630 nonzeros  0s
# 197 rows, 196 cols, 574 nonzeros  0s
#
# Solving MIP model with:
#    197 rows
#    196 cols (196 binary, 0 integer, 0 implied int., 0 continuous)
#    574 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic; L => Sub-MIP;
#      P => Empty MIP; R => Randomized rounding; S => Solve LP; T => Evaluate node; U => Unbounded;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   0               inf                  inf        0      0      0         0     0.0s
#  R       0       0         0 100.00%   0               0                  0.00%        0      0      0        58     0.0s
#          1       0         1 100.00%   0               0                  0.00%        0      0      0        58     0.0s
#
# Solving report
#   Status            Optimal
#   Primal bound      0
#   Dual bound        0
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0
#   Solution status   feasible
#                     0 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            0.01 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     58 (total)
#                     0 (strong br.)
#                     0 (separation)
#                     0 (heuristics)
# Termination status: OPTIMAL
# Optimal objective value: 0.0
# Selected medoid points:
# ======================
# New Cluster
# Medoid Point: 1
# Assigned points
# Point: 1
# ======================
# New Cluster
# Medoid Point: 5
# Assigned points
# Point: 5
# Point: 6
# Point: 9
# Point: 13
# Point: 14
# ======================
# New Cluster
# Medoid Point: 12
# Assigned points
# Point: 2
# Point: 3
# Point: 4
# Point: 7
# Point: 8
# Point: 10
# Point: 11
# Point: 12
